# %%
#IMPORTING LIBRARIES

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install numpy

# %%
#LETS CREATE SOME DATA to plot graphs

# %%
import numpy as np
x=np.linspace(0,10,20)
y=np.random.randint(1,50,20)

# %%
x #linspace divides 0-10 ,twenty equal divisons
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y #random numbers from range 1 to 50
# Out:
# array([ 8,  9, 30, 19,  5, 33, 28, 41, 48, 25, 31,  6, 19,  9, 25, 43, 16,
#        11, 45, 17])

# %%
x.size
# Out:
# 20

# %%
y.size
# Out:
# 20

# %%
#OPERATION THAT CAN BE PERFORMED
#x and y
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
#  '_pylab_helpers',
# ...

# %%
#UNIVARIATE ANALYSIS:

# %%
plt.plot(x)#x is in a sorted mannner

# %%
plt.plot(y)#its not sorted

# %%
print(np.sort(y))#lets sort y and plot
# Out:
# [ 5  6  8  9  9 11 16 17 19 19 25 25 28 30 31 33 41 43 45 48]

# %%
y=np.sort(y)
plt.plot(y)

# %%
#Bivariate
plt.plot(x,y)

# %%
#for color
plt.plot(x,y,color='r')

# %%
plt.plot(x,y,color='g')

# %%
#LETS NAME XAXIS AND Y AXIS and GIVE NAME TO THE GRAPH
plt.plot(x,y,color='r')
plt.xlabel('X_axis')
plt.ylabel('Y_axis')
plt.title('Rnadom plot')
plt.show()

# %%
y2=y*x #HERE SUBPLOT IS FOR FIRST ANFD ANOTHER FOR SECOND REMEMBER subplot should be specifiyed first then plot
plt.subplot(1,2,1)
plt.plot(x,y,color='r')
plt.subplot(1,2,2)
plt.plot(x,y2,color='b')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro')#o as the maker and it looks like the scatter plot
plt.subplot(1,2,2)
plt.plot(x,y2,'bo')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro-')#o as the maker on the line and it looks like the scatter plot along line
plt.subplot(1,2,2)
plt.plot(x,y2,'bo-')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro--')#  line as the maker on the line and it looks like the scatter plot
plt.subplot(1,2,2)
plt.plot(x,y2,'bo--')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r*-')#  line as the maker on the line and it looks like the scatter plot
plt.subplot(1,2,2)
plt.plot(x,y2,'b*-')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r*')# star as the maker on the line and it looks like the scatter plot
plt.subplot(1,2,2)
plt.plot(x,y2,'b*')

# %%
#TO ARANGE THE MARKER SIZE
plt.subplot(1,2,1)
plt.plot(x,y,'r*',markersize=5)# star as the maker on the line and it looks like the scatter plot
plt.subplot(1,2,2)
plt.plot(x,y2,'b*',markersize=10)

# %%
#matplotlib is object oriented and drawing object oriented figures gives more control over the figure
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,1,1])#X starts from 0.1 to 1 and similary y 0.1 to 1
axes.plot(x,y,'r')
plt.xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,1,1])#X starts from 0.1 to 1 and similary y 0.1 to 1
                  #X ,#Y,#X*,#Y*  
axes.plot(x,y,'r')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Set Title of Random')
# Out:
# Text(0.5, 1.0, 'Set Title of Random')

# %%
#Operations that can be performed
dir(axes)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_locator',
#  '_axisbelow',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_axis_map',
#  '_get_clipping_extent_bbox',
#  '_get_lines',
#  '_get_patches_for_fill',
# ...

# %%
fig=plt.figure()#HERE WE PLOT WITHIN PLOT BECAUSE OF OBJECT ORIENTED PROGRAMMING.
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
#This helps us to plot within the plot

# %%
fig=plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.1,0.6,0.4,0.3])
axes1.plot(x,y,'r')
axes2.plot(x,y2,'g')
axes1.set_xlabel('X')
axes2.set_ylabel('Y')
axes1.set_title('Y plot')
axes2.set_xlabel('X')
axes2.set_ylabel('Y')
axes2.set_title('Y2 PLOT')
#This helps us to plot within the plot 
#HERE AXES1---TWO DIFFERENT PLOTS (OUTER PLOT)
#HERE AXES2---TWO DIFFERENT PLOTS (INNER PLOT)
# Out:
# Text(0.5, 1.0, 'Y2 PLOT')

# %%
#PLT.SUBPLOTS
fig,ax=plt.subplots(1,2)#---TWO SUBPLOTS
ax[0].plot(x,y,'b')
ax[1].plot(x,y,'r')

# %%
fig,ax=plt.subplots(1,2)
for axes in ax:
    axes.plot(x,y,'g')

# %%
fig,ax=plt.subplots(1,2)
color=['r','g']
for i,axes in enumerate(ax):
    axes.plot(x,y,color[i])
#DIFFEENT COLOR FOR SAME DATA IN TWO PLOTS

# %%
fig,ax=plt.subplots(1,2)
color=['r','g']
data=[y,y2]
for i,axes in enumerate(ax):
    axes.plot(x,data[i],color[i])
#DIFFERENT DATA AND DIFFERENT COLOR.

# %%
fig,ax=plt.subplots(1,2)
color=['r','g']
data=[y,y2]
for i,axes in enumerate(ax):
    axes.plot(x,data[i],color[i])
fig.tight_layout()#-----automatically adjust figures layout i.e overlapping of the text of figures.etc..
#DIFFERENT DATA AND DIFFERENT COLOR.

# %%
fig,ax=plt.subplots(figsize=(8,4),dpi=50)#dpi---dot per index---whole size changes
ax.plot(x,y,'r')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random Number PLot')
#to save figure---[fig.savefig('randomfile.png',dpi=300)]#randomfile---file name
# Out:
# Text(0.5, 1.0, 'Random Number PLot')

# %%
fig,ax=plt.subplots(figsize=(8,4),dpi=150)#dpi---dot per index---whole size changes
ax.plot(x,y,'r')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random Number PLot')
#to save figure---[fig.savefig('randomfile.png',dpi=300)]#randomfile---file name
# Out:
# Text(0.5, 1.0, 'Random Number PLot')

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend()#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=0)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=1)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=2)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=3)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=4)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=5)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
#BOTH FIGURES IN ONE PLOT AND WHAT EACH REPRESENTED IN DIFFERENT COLOR
fig,ax=plt.subplots(figsize=(8,4),dpi=100)
ax.plot(x,y,label='Y')
ax.plot(x,y2,label='Y*X')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random NUMBER PLOT')
ax.legend(loc=6)#---SHOWS WHERE LABEL TO APPEAR
#fig.savefig('randomfile.png',dpi=300)

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b.-')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b.--')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b*-')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b,--')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b1--')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b2--',markersize=12,linewidth=3)

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b--',markersize=12,linewidth=3,color='r')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b--',markersize=12,linewidth=3,color='#56787652')

# %%
fig,ax=plt.subplots()
ax.plot(x,y,'b--',markersize=12,linewidth=3,color='#00445654')

# %%
fig,ax=plt.subplots(1,3,figsize=(12,4))#----3 images
ax[0].plot(x,y,x,y2)#Another way of getting two plots in one figure
ax[1].plot(x,y**2,'k')
ax[2].plot(x,y,x,y2)#two plots in one figuye
ax[2].set_ylim([0,100])#sets up y limit for figure 3
ax[2].set_xlim([1,4])#sets up x limit for figure 3
# Out:
# (1.0, 4.0)

# %%
plt.scatter(x,y)

# %%
plt.bar(x,height=1)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.bar(x,height=1,width=0.5)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.bar(y,height=1,width=0.5)
# Out:
# <BarContainer object of 20 artists>

# %%
from random import sample
data=sample(range(1,10000),10)
data #random samples between 1-10000 ....10 samples.
# Out:
# [1585, 9235, 5298, 6193, 5488, 8129, 315, 7255, 5705, 7895]

# %%
plt.hist(data,rwidth=0.8)
# Out:
# (array([1., 1., 0., 0., 0., 2., 2., 1., 2., 1.]),
#  array([ 315., 1207., 2099., 2991., 3883., 4775., 5667., 6559., 7451.,
#         8343., 9235.]),
#  <a list of 10 Patch objects>)

# %%
data=[np.random.normal(0,std,100) for std in range(1,10)]

# %%
plt.boxplot(data,vert=True,patch_artist=True)#VERT MAKES THE PLOT VERTICAL
plt.show()#patch_artist : bool, optional (False)
   # If `False` produces boxes with the Line2D artist. Otherwise,
    #boxes and drawn with Patch artists.

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].plot(x,y,x,y2)
ax[1].plot(x,np.exp(x))#exponentishal data

fig.tight_layout
# Out:
# <bound method Figure.tight_layout of <Figure size 720x288 with 2 Axes>>

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].plot(x,y,x,y2)
ax[1].plot(x,np.exp(x))#exponentishal data
ax[1].set_yscale('log')
fig.tight_layout
# Out:
# <bound method Figure.tight_layout of <Figure size 720x288 with 2 Axes>>

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x,y2,lw=2)

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x,y2,lw=2)
ax.set_xticks([])#no x ticks as we didnt pass anything in the list.
# Out:
# []

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x,y2,lw=2)
ax.set_xticks([1,2,3,4,5])#no we have ticks.

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x,y2,lw=2)
ax.set_xticks([1,3,5,10])#no we have ticks.

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x,y2,lw=2)
ax.set_xticks([1,3,5,10])
ax.set_yticks([0,100,500])
ax.set_xticklabels([r'$\alpha$',r'$\beta$',r'$\gamma$',r'$\delta$',r'$\epsilon$'],fontsize=18)
# Out:
# [Text(0, 0, '$\\alpha$'),
#  Text(0, 0, '$\\beta$'),
#  Text(0, 0, '$\\gamma$'),
#  Text(0, 0, '$\\delta$')]

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x,y2,lw=2)
ax.set_xticks([1,3,5,10])
ax.set_yticks([0,100,500,1000])
ax.set_xticklabels([r'a',r'b',r'c',r'$\delta$',r'$\epsilon$'],fontsize=18)
# Out:
# [Text(0, 0, 'a'), Text(0, 0, 'b'), Text(0, 0, 'c'), Text(0, 0, '$\\delta$')]

# %%
from matplotlib import ticker

# %%
fig,ax=plt.subplots()
ax.plot(x,y2)
ax.set_title('Scientific Notation')
formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)

# %%
fig,ax=plt.subplots()
ax.plot(x,y2)
ax.set_title('Scientific Notation')
formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,-2))
ax.yaxis.set_major_formatter(formatter)

# %%
fig,ax=plt.subplots()
ax.plot(x,y2)
ax.set_title('Scientific Notation')
formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,-1))
ax.yaxis.set_major_formatter(formatter)

# %%
#Thank you by Rama Veera Isaiah
